# %%
# !pip install black
# !pip install "black[jupyter]"
# Out:
# Requirement already satisfied: black in c:\users\anton\anaconda3\lib\site-packages (24.10.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\anton\anaconda3\lib\site-packages (from black) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\anton\anaconda3\lib\site-packages (from black) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\anton\anaconda3\lib\site-packages (from black) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\anton\anaconda3\lib\site-packages (from black) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\anton\anaconda3\lib\site-packages (from black) (4.3.7)
# Requirement already satisfied: colorama in c:\users\anton\anaconda3\lib\site-packages (from click>=8.0.0->black) (0.4.6)
# Requirement already satisfied: black[jupyter] in c:\users\anton\anaconda3\lib\site-packages (24.10.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (4.3.7)
# Requirement already satisfied: ipython>=7.8.0 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (8.30.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in c:\users\anton\anaconda3\lib\site-packages (from black[jupyter]) (6.2.0)
# Requirement already satisfied: colorama in c:\users\anton\anaconda3\lib\site-packages (from click>=8.0.0->black[jupyter]) (0.4.6)
# Requirement already satisfied: decorator in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\anton\anaconda3\lib\site-packages (from ipython>=7.8.0->black[jupyter]) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\anton\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.8.0->black[jupyter]) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\anton\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]) (0.8.4)
# Requirement already satisfied: executing in c:\users\anton\anaconda3\lib\site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\anton\anaconda3\lib\site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\anton\anaconda3\lib\site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (0.2.2)

# %%
# !black "hirehi_parsing.ipynb"
# Out:
# Usage: black [OPTIONS] SRC ...
# Try 'black -h' for help.
#
# Error: Invalid value for 'SRC ...': Path 'hirehi_parsing.ipynb' does not exist.

# %%
import requests

# %% [markdown]
# ### Получение основного датасета

# %%
url = "https://hirehi.ru/api/search/jobs?limit=50"
page = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connection.py:207, in HTTPConnection._new_conn(self)
#     206 except SocketTimeout as e:
# --> 207     raise ConnectTimeoutError(
#     208         self,
#     209         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     210     ) from e
#     212 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001FFB0CD2510>, 'Connection to hirehi.ru timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='hirehi.ru', port=443): Max retries exceeded with url: /api/search/jobs?limit=50 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FFB0CD2510>, 'Connection to hirehi.ru timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 url = "https://hirehi.ru/api/search/jobs?limit=50"
# ----> 2 page = requests.get(url)
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Anton\anaconda3\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='hirehi.ru', port=443): Max retries exceeded with url: /api/search/jobs?limit=50 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FFB0CD2510>, 'Connection to hirehi.ru timed out. (connect timeout=None)'))

# %%
page

# %%
print(page.json())

# %%
a = [page.json()["limit"], page.json()["page"], page.json()["total_count"]]
a

# %%
import math

pageamount = math.ceil(a[2] / a[0])
pageamount

# %%
data = page.json()
jobs = data["jobs"]
first = jobs[0]
print(first.keys())

# %%
def get_page(p):
    url = f"https://hirehi.ru/api/search/jobs?page={p}&limit=50"
    response = requests.get(url)
    jobs = response.json()["jobs"]
    clean_data = []
    for i in jobs:
        cleanvac = {
            "id": i.get("id"),
            "title": i.get("title"),
            "category": i.get("category"),
            "company": i.get("company"),
            "format": i.get("format"),
            "level": i.get("level"),
            "salary": i.get("salary"),
        }
        clean_data.append(cleanvac)
    return clean_data

# %%
from tqdm.notebook import tqdm

# %%
infa = []
for p in tqdm(range(1, pageamount + 1)):
    try:
        infa.extend(get_page(p))
        sleep(3)
    except:
        print(p)

# %%
import pandas as pd

df = pd.DataFrame(infa)
print(df.shape)
df.head(10)

# %% [markdown]
# Далее соберем ссылки:</br>
# .NET Developer</br>
# https://hirehi.ru/development/net-developer-36177</br>
# графический дизайнер</br>
# https://hirehi.ru/design/graficheskii-dizainer-36174</br>
# Сылки выглядят таким образом , то есть https://hirehi.ru/{category}/{title}-{id}
# </br>Все title приведены к нижнему регистру, текст на русском транслитерирован, все символы, кроме букв заменены на "-", крайние дефисы удалены, для этого можно использовать модуль **transliterate**.
# Создадим дополнительные колонки для транслитерации русского текста в колонках **title** и **category**.

# %% [markdown]
# Если текст состоит из слов только на английском, то выводится none, значит текст, который написан на английском оставляем как есть. </br> Такжде слэши удаляются и не заменяются на дефисы, как должно быть с карточкой UX/UI дизайнер https://hirehi.ru/design/ux-ui-dizainer-36159

# %%
df["title_trans"] = df["title"]
df["id_trans"] = df["id"]
df.head(10)

# %%
df["title_trans"] = df["title_trans"].astype(str).str.lower()
df["id_trans"] = df["id_trans"].astype(str)
df.head(10)

# %%
df["title_trans"] = (
    df["title_trans"]
    .str.replace(r"[^\w]", "-", regex=True)
    .str.replace(r"_", "-", regex=True)
)
df

# %% [markdown]
# нужно удалить повторяющиеся дефисы и дефисы в начале/конце

# %%
df["title_trans"] = df["title_trans"].str.replace(r"-+", "-", regex=True)
df

# %%
df["title_trans"] = df["title_trans"].str.strip("-")
df

# %% [markdown]
# напишем функцию, которая будет транслитерировать русский текст, а английский оставлять как есть

# %%
def makelink1(i):
    letters = {
        "а": "a",
        "б": "b",
        "в": "v",
        "г": "g",
        "д": "d",
        "е": "e",
        "ё": "e",
        "ж": "zh",
        "з": "z",
        "и": "i",
        "й": "i",
        "к": "k",
        "л": "l",
        "м": "m",
        "н": "n",
        "о": "o",
        "п": "p",
        "р": "r",
        "с": "s",
        "т": "t",
        "у": "u",
        "ф": "f",
        "х": "h",
        "ц": "ts",
        "ч": "ch",
        "ш": "sh",
        "щ": "sch",
        "ъ": "",
        "ы": "y",
        "ь": "",
        "э": "e",
        "ю": "yu",
        "я": "ya",
    }
    ready = ""
    for s in i:
        if s in letters:
            ready += letters[s]
        else:
            ready += s
    return ready

# %%
df["title_trans"] = df["title_trans"].apply(makelink1)
df

# %% [markdown]
# Теперь соберем ссылку в том виде, в котором она должна быть <br>
# https://hirehi.ru/{category}/{title}-{id}

# %%
df["link"] = (
    "https://hirehi.ru/"
    + df["category"]
    + "/"
    + df["title_trans"]
    + "-"
    + df["id_trans"]
)
df

# %% [markdown]
# мы получили ссылки, но можно заметить такую проблему, что transliterate заменяет буквы не так "по-русски", в наших ссылках пишется **ux-ui-dizajner**, когда в оригинальной ссылке используется **ux-ui-dizainer**
# значит библиотека не сможет "правильно" транслитерировать наш текст. Поэтому напишем словарь, с помощью которого можно будет просто заменять русскую букву на английскую, без дополнительных правил библиотеки, когда две гласные стоят рядом и происходит удвоение.

# %%
df.drop(columns=["title_trans", "id_trans"], inplace=True)
df

# %% [markdown]
# ### Получение навыков для вакансий

# %% [markdown]
# Импорт библиотек:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Для получения навыков определим следующую функцию:

# %%
def get_skills(url):
    try:
        response = requests.get(url)
        page = BeautifulSoup(response.text, "html")
        tags_required = page.find_all("a", class_="job-tag")
        skills = []
        for tag in tags_required:
            skill = tag.text.lower().strip()
            skills.append(skill)
        return skills
    except Exception as e:
        print(f"Exception on {url}")
        return []

# %% [markdown]
# Получаем навыки из карточки вакасии:

# %%
data["skills"] = data.apply(lambda x: get_skills(x.link), axis=1)

# %% [markdown]
# Проанализируем результат:

# %%
data["skills"].value_counts()

# %% [markdown]
# Только для 55 вакансий получили пустой массив, при этом не было ошибок при чтении ссылок. Таким образом, удалось получить актуальный список требований к вакансии.
#
# Также можно заметить, что в данных почти отсутствуют вакансии с одинаковым набором требований.

# %% [markdown]
# Сохраним результат:

# %%
data.to_csv("hirehi_vacancys.csv")
